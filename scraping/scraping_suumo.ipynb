# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np

# %%
base_url = "https://suumo.jp/jj/chintai/ichiran/FR301FC001/?fw2=&mt=9999999&cn=9999999&ta=13&et=9999999&sc=13101&shkr1=03&ar=030&bs=040&ct=9999999&shkr3=03&shkr2=03&srch_navi=1&mb=0&shkr4=03&cb=0.0"
response = requests.get(base_url)
soup     = BeautifulSoup(response.content, "lxml")
items    = soup.find(class_="cassetteitem")

# %%
# スクレイピングした HTML情報出力
with open("test.txt", "w", encoding="utf-8") as f:
    f.write(str(items))

print("Data has been successfully written to test.txt")
# Out:
# Data has been successfully written to test.txt

# %%
# 各物件情報の取得
property_name     = items.find(class_="cassetteitem_content-title").get_text() if items.find(class_="cassetteitem_content-title") else None
category          = items.find(class_="cassetteitem_content-label").span.get_text() if items.find(class_="cassetteitem_content-label") else None
address           = items.find(class_="cassetteitem_detail-col1").get_text() if items.find(class_="cassetteitem_detail-col1") else None
nearest_stations  = [station.get_text() for station in items.find_all(class_="cassetteitem_detail-text")] if items.find_all(class_="cassetteitem_detail-text") else None
construction_info = items.find(class_="cassetteitem_detail-col3").find_all("div") if items.find(class_="cassetteitem_detail-col3") else None
years_since_const = construction_info[0].get_text() if construction_info and len(construction_info) > 0 else None
number_of_floors  = construction_info[1].get_text() if construction_info and len(construction_info) > 1 else None
floor_number_td   = items.select_one("tr.js-cassette_link .cassetteitem_other-col03")
floor_number      = floor_number_td.get_text(strip=True) if floor_number_td else None
rent_info         = items.select_one(".cassetteitem_other tbody .js-cassette_link")
rent_admin_fee    = " / ".join([item.get_text(strip=True) for item in rent_info.select(".cassetteitem_price--rent, .cassetteitem_price--administration")]) if rent_info else None
deposit_gratuity  = " / ".join([price.get_text(strip=True) for price in rent_info.select(".cassetteitem_price--deposit, .cassetteitem_price--gratuity")]) if rent_info else None
layout_total_area = " / ".join([detail.get_text(strip=True) for detail in rent_info.select(".cassetteitem_madori, .cassetteitem_menseki")]) if rent_info else None


# 各物件情報の表示
print("物件名称 (Property Name):", property_name)
print("カテゴリー (Category):", category)
print("住所 (Address):", address)
print("最寄り駅 (Nearest Stations):", nearest_stations)
print("築年数 (Years Since Construction):", years_since_const)
print("階建 (Number of Floors):", number_of_floors)
print("階数 (Floor Number):", floor_number)
print("賃料/管理費 (Rent/Administration Fee):", rent_admin_fee)
print("敷金/礼金 (Deposit/Key Money):", deposit_gratuity)
print("間取り/占有面積 (Layout/Total Area):", layout_total_area)
# Out:
# 物件名称 (Property Name): コスモグラシア内神田
# カテゴリー (Category): 賃貸マンション
# 住所 (Address): 東京都千代田区内神田２
# 最寄り駅 (Nearest Stations): ['ＪＲ山手線/神田駅 歩4分', '東京メトロ丸ノ内線/大手町駅 歩6分', 'ＪＲ総武線快速/新日本橋駅 歩9分']
# 築年数 (Years Since Construction): 築2年
# 階建 (Number of Floors): 7階建
# 階数 (Floor Number): None
# 賃料/管理費 (Rent/Administration Fee): 24.8万円 / 20000円
# 敷金/礼金 (Deposit/Key Money): - / -
# 間取り/占有面積 (Layout/Total Area): 2LDK / 47.54m2

# %%
# 物件画像・間取り画像・詳細URLの取得
property_image_element = items.find(class_="cassetteitem_object-item")
property_image_url = property_image_element.img["rel"] if property_image_element and property_image_element.img else None

floor_plan_image_element = items.find(class_="casssetteitem_other-thumbnail")
floor_plan_image_url = floor_plan_image_element.img["rel"] if floor_plan_image_element and floor_plan_image_element.img else None

property_link_element = items.select_one("a[href*='/chintai/jnc_']")
property_link = "https://suumo.jp/chintai/jnc_000088343514/?bc=100376326647" + property_link_element['href'] if property_link_element else None ## 不動産サイトから詳細URLリンクを読み解き作成

# 物件画像・間取り画像・詳細URLの表示
print("物件画像 URL (Property Image URL):", property_image_url)
print("間取り情報画像 URL (Floor Plan Image URL):", floor_plan_image_url)
print("物件リンク (Property Link):", property_link)
# Out:
# 物件画像 URL (Property Image URL): https://img01.suumo.com/front/gazo/fr/bukken/572/100373752572/100373752572_gw.jpg
# 間取り情報画像 URL (Floor Plan Image URL): https://img01.suumo.com/front/gazo/fr/bukken/647/100376326647/100376326647_co.jpg
# 物件リンク (Property Link): https://suumo.jp/chintai/jnc_000088343514/?bc=100376326647/chintai/jnc_000088343514/?bc=100376326647

# %%
# 基本URLと最大ページ数の設定
base_url = "https://suumo.jp/jj/chintai/ichiran/FR301FC001/?fw2=&mt=9999999&cn=9999999&ta=13&et=9999999&sc=13101&shkr1=03&ar=030&bs=040&ct=9999999&shkr3=03&shkr2=03&srch_navi=1&mb=0&shkr4=03&cb=0.0&page={}"
max_page = 5  # 最大ページ数

all_data = []

for page in range(1, max_page + 1):
    url = base_url.format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    items = soup.findAll("div", {"class": "cassetteitem"})


    print("page", page, "items", len(items))

    for item in items:
        base_data = {}
        base_data["名称"]     = item.find("div", {"class": "cassetteitem_content-title"}).get_text(strip=True) if item.find("div", {"class": "cassetteitem_content-title"}) else None
        base_data["カテゴリ"] = item.find("div", {"class": "cassetteitem_content-label"}).span.get_text(strip=True) if item.find("div", {"class": "cassetteitem_content-label"}) else None
        base_data["アドレス"] = item.find("li", {"class": "cassetteitem_detail-col1"}).get_text(strip=True) if item.find("li", {"class": "cassetteitem_detail-col1"}) else None
        
        # 駅のアクセス情報をまとめて取得
        base_data["アクセス"] = ", ".join([station.get_text(strip=True) for station in item.findAll("div", {"class": "cassetteitem_detail-text"})])

        construction_info = item.find("li", {"class": "cassetteitem_detail-col3"}).find_all("div") if item.find("li", {"class": "cassetteitem_detail-col3"}) else None
        base_data["築年数"] = construction_info[0].get_text(strip=True) if construction_info and len(construction_info) > 0 else None
        base_data["構造"] = construction_info[1].get_text(strip=True) if construction_info and len(construction_info) > 1 else None

        tbodys = item.find("table", {"class": "cassetteitem_other"}).findAll("tbody")

        for tbody in tbodys:
            data = base_data.copy()
            # 階数情報の正確な取得
            floor_info = tbody.find_all("td")[2].get_text(strip=True) if len(tbody.find_all("td")) > 2 else None
            data["階数"]   = floor_info
            data["家賃"]   = tbody.select_one(".cassetteitem_price--rent").get_text(strip=True) if tbody.select_one(".cassetteitem_price--rent") else None
            data["管理費"] = tbody.select_one(".cassetteitem_price--administration").get_text(strip=True) if tbody.select_one(".cassetteitem_price--administration") else None
            data["敷金"]   = tbody.select_one(".cassetteitem_price--deposit").get_text(strip=True) if tbody.select_one(".cassetteitem_price--deposit") else None
            data["礼金"]   = tbody.select_one(".cassetteitem_price--gratuity").get_text(strip=True) if tbody.select_one(".cassetteitem_price--gratuity") else None
            data["間取り"] = tbody.select_one(".cassetteitem_madori").get_text(strip=True) if tbody.select_one(".cassetteitem_madori") else None
            data["面積"]   = tbody.select_one(".cassetteitem_menseki").get_text(strip=True) if tbody.select_one(".cassetteitem_menseki") else None

            # 物件画像・間取り画像・詳細URLの取得を最後に行う
            property_image_element = item.find(class_="cassetteitem_object-item")
            data["物件画像URL"] = property_image_element.img["rel"] if property_image_element and property_image_element.img else None

            floor_plan_image_element = item.find(class_="casssetteitem_other-thumbnail")
            data["間取画像URL"] = floor_plan_image_element.img["rel"] if floor_plan_image_element and floor_plan_image_element.img else None

            property_link_element = item.select_one("a[href*='/chintai/jnc_']")
            data["物件詳細URL"] = "https://suumo.jp" +property_link_element['href'] if property_link_element else None ## 不動産サイトから詳細URLリンクを読み解き作成

            all_data.append(data)
# Out:
# page 1 items 30
# page 2 items 30
# page 3 items 30
# page 4 items 30
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 45
#      43 # 物件画像・間取り画像・詳細URLの取得を最後に行う
#      44 property_image_element = item.find(class_="cassetteitem_object-item")
# ---> 45 data["物件画像URL"] = property_image_element.img["rel"] if property_image_element and property_image_element.img else None
#      47 floor_plan_image_element = item.find(class_="casssetteitem_other-thumbnail")
#      48 data["間取画像URL"] = floor_plan_image_element.img["rel"] if floor_plan_image_element and floor_plan_image_element.img else None
#
# File c:\Users\kouji\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'rel'

# %%
df = pd.DataFrame(all_data)
df = df.drop_duplicates() # 重複データの削除
df.head(2)
# Out:
#            名称     カテゴリ         アドレス  \
# 0  コスモグラシア内神田  賃貸マンション  東京都千代田区内神田２
# 1  コスモグラシア内神田  賃貸マンション  東京都千代田区内神田２
#
#                                                 アクセス  築年数   構造  階数      家賃  \
# 0  ＪＲ山手線/神田駅 歩4分, 東京メトロ丸ノ内線/大手町駅 歩6分, ＪＲ山手線/東京駅 歩14分  築2年  7階建  5階  24.8万円
# 1  ＪＲ山手線/神田駅 歩4分, 東京メトロ丸ノ内線/大手町駅 歩6分, ＪＲ山手線/東京駅 歩14分  築2年  7階建  3階  26.2万円
#
#       管理費 敷金 礼金   間取り       面積  \
# 0  20000円  -  -  2LDK  47.54m2
# 1  20000円  -  -  2LDK   47.6m2
#
#                                              物件画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/4...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/4...
#
#                                              間取画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/8...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/8...
#
#                                              物件詳細URL
# 0  https://suumo.jp/chintai/jnc_000088343514/?bc=...
# 1  https://suumo.jp/chintai/jnc_000088343514/?bc=...

# %%
# google スプレッドシート 書き込み・読み込み
import gspread
from google.oauth2 import service_account
from google.oauth2.service_account import Credentials
from gspread_dataframe import get_as_dataframe
from gspread_dataframe import set_with_dataframe

# %%
from dotenv import load_dotenv
import os

# 環境変数の読み込み
load_dotenv(r'C:\Users\kouji\Desktop\tech0\step3\step3-1\scraping\.env.gspread')

# 環境変数から認証情報を取得
SPREADSHEET_ID = os.getenv("SPREADSHEET_ID")
PRIVATE_KEY_PATH = os.getenv("PRIVATE_KEY_PATH")

# %%
print(PRIVATE_KEY_PATH)
# Out:
# C:\Users\kouji\Desktop\tech0\step3\step3-1\scraping\movemate-424413-ac7aebdc33d4.json

# %%
print(SPREADSHEET_ID)
# Out:
# 14ZMZitNS210QFzRDbfVMYg3vZGjhkIEVAbHsLi6ecAY

# %%
with open(r'C:\Users\kouji\Desktop\tech0\step3\step3-1\.env.gspread', 'r') as file:
    env_contents = file.read()

print(env_contents)
# Out:
# SPREADSHEET_ID=14ZMZitNS210QFzRDbfVMYg3vZGjhkIEVAbHsLi6ecAY
# PRIVATE_KEY_PATH=C:\Users\kouji\Desktop\tech0\step3\step3-1\scraping\movemate-424413-ac7aebdc33d4.json
# SPREADSHEET_User_ID=1qWKIN7piCqINtzFc9vnT6nRxoqeLWGVCgPoKaDkCHzE

# %%
# googleスプレッドシートの認証 jsonファイル読み込み(key値はGCPから取得)
SP_CREDENTIAL_FILE = PRIVATE_KEY_PATH

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]

credentials = Credentials.from_service_account_file(
    SP_CREDENTIAL_FILE,
    scopes=scopes
)
gc = gspread.authorize(credentials)


SP_SHEET_KEY = SPREADSHEET_ID # d/〇〇/edit の〇〇部分
sh  = gc.open_by_key(SP_SHEET_KEY)

# %%
# 取得した不動産データの書き込み
SP_SHEET_wr     = 'test' # sheet名
worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
set_with_dataframe(worksheet_wr, df)

# %%
# 不動産データの取得
SP_SHEET     = 'test' # sheet名
worksheet = sh.worksheet(SP_SHEET) # シートのデータ取得
pre_data  = worksheet.get_all_values()
col_name = pre_data[0][:]
new_df = pd.DataFrame(pre_data[1:], columns=col_name) # 一段目をカラム、以下データフレームで取得

# %%
new_df.head(2)
# Out:
#            名称     カテゴリ         アドレス  \
# 0  コスモグラシア内神田  賃貸マンション  東京都千代田区内神田２
# 1  コスモグラシア内神田  賃貸マンション  東京都千代田区内神田２
#
#                                                 アクセス  築年数   構造  階数      家賃  \
# 0  ＪＲ山手線/神田駅 歩4分, 東京メトロ丸ノ内線/大手町駅 歩6分, ＪＲ山手線/東京駅 歩14分  築2年  7階建  5階  24.8万円
# 1  ＪＲ山手線/神田駅 歩4分, 東京メトロ丸ノ内線/大手町駅 歩6分, ＪＲ山手線/東京駅 歩14分  築2年  7階建  3階  26.2万円
#
#       管理費 敷金 礼金   間取り       面積  \
# 0  20000円  -  -  2LDK  47.54m2
# 1  20000円  -  -  2LDK   47.6m2
#
#                                              物件画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/4...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/4...
#
#                                              間取画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/8...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/8...
#
#                                              物件詳細URL
# 0  https://suumo.jp/chintai/jnc_000088343514/?bc=...
# 1  https://suumo.jp/chintai/jnc_000088343514/?bc=...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   名称       640 non-null    object
#  1   カテゴリ     640 non-null    object
#  2   アドレス     640 non-null    object
#  3   アクセス     640 non-null    object
#  4   築年数      640 non-null    object
#  5   構造       640 non-null    object
#  6   階数       640 non-null    object
#  7   家賃       640 non-null    object
#  8   管理費      640 non-null    object
#  9   敷金       640 non-null    object
#  10  礼金       640 non-null    object
#  11  間取り      640 non-null    object
#  12  面積       640 non-null    object
#  13  物件画像URL  640 non-null    object
#  14  間取画像URL  640 non-null    object
#  15  物件詳細URL  640 non-null    object
# dtypes: object(16)
# memory usage: 80.1+ KB

# %%
new_df['築年数'] = new_df["築年数"].apply( lambda x: 0 if x=='新築' else int(re.split('[築年]', x )[1]) )

# %%
def get_most_floor(x):
    if ('階建' not in x) :
        return np.nan
    elif('B' not in x) :
        list = re.findall(r'(\d+)階建',str(x))
        list = map(int, list)
        min_value = min(list)
        return min_value

new_df['構造'] = new_df['構造'].apply(get_most_floor)
print(new_df['構造'].head(5))
# Out:
# 0     7
# 1     7
# 2     7
# 3    12
# 4    12
# Name: 構造, dtype: int64

# %%
def get_floor(x):
    if ('階' not in x) :
        return np.nan
    elif('B' not in x) :
        list = re.findall(r'(\d+)階',str(x))
        # time_listを数値型に変換
        list = map(int, list)
        # time_listの最小値をmin_valueに代入
        min_value = min(list)
        return min_value
    else:
        list = re.findall(r'(\d+)階',str(x))
        # time_listを数値型に変換
        list = map(int, list)
        # time_listの最小値をmin_valueに代入
        min_value = -1*min(list)
        return min_value

new_df['階数'] = new_df['階数'].apply(get_floor)
print(new_df['階数'].head(5))
# Out:
# 0    5.0
# 1    3.0
# 2    5.0
# 3    7.0
# 4    4.0
# Name: 階数, dtype: float64

# %%
def change_fee(x):
    if ('万円' not in x) :
        return np.nan
    else:
        return float(x.split('万円')[0])

new_df['家賃'] = new_df['家賃'].apply(change_fee)
new_df['敷金'] = new_df['敷金'].apply(change_fee)
new_df['礼金'] = new_df['礼金'].apply(change_fee)

# %%
def change_fee2(x):
    if ('円' not in x) :
        return np.nan
    else:
        return float(x.split('円')[0])


new_df['管理費'] = new_df['管理費'].apply(change_fee2)

# %%
new_df['面積'] = new_df['面積'].apply(lambda x: float(x[:-2]))

# %%
new_df['区'] = new_df["アドレス"].apply(lambda x : x[x.find("都")+1:x.find("区")+1])

# %%
new_df['市町'] = new_df["アドレス"].apply(lambda x : x[x.find("区")+1 :-1])

# %%
def split_access(row):
    accesses = row['アクセス'].split(', ')
    results = {}

    for i, access in enumerate(accesses, start=1):
        if i > 3:
            break  # 最大3つのアクセス情報のみを考慮

        parts = access.split('/')
        if len(parts) == 2:
            line_station, walk = parts
            # ' 歩'で分割できるか確認
            if ' 歩' in walk:
                station, walk_min = walk.split(' 歩')
                # 歩数の分の数値だけを抽出
                walk_min = int(re.search(r'\d+', walk_min).group())
            else:
                station = None
                walk_min = None
        else:
            line_station = access
            station = walk_min = None

        results[f'アクセス①{i}線路名'] = line_station
        results[f'アクセス①{i}駅名'] = station
        results[f'アクセス①{i}徒歩(分)'] = walk_min

    return pd.Series(results)

# 新しい列をデータフレームに適用
new_df = new_df.join(new_df.apply(split_access, axis=1))

# %%
new_df.head(2)
# Out:
#            名称     カテゴリ         アドレス  \
# 0  コスモグラシア内神田  賃貸マンション  東京都千代田区内神田２
# 1  コスモグラシア内神田  賃貸マンション  東京都千代田区内神田２
#
#                                                 アクセス  築年数  構造   階数    家賃  \
# 0  ＪＲ山手線/神田駅 歩4分, 東京メトロ丸ノ内線/大手町駅 歩6分, ＪＲ山手線/東京駅 歩14分    2   7  5.0  24.8
# 1  ＪＲ山手線/神田駅 歩4分, 東京メトロ丸ノ内線/大手町駅 歩6分, ＪＲ山手線/東京駅 歩14分    2   7  3.0  26.2
#
#        管理費  敷金  ...   市町 アクセス①1線路名  アクセス①1駅名 アクセス①1徒歩(分)  アクセス①2線路名 アクセス①2駅名  \
# 0  20000.0 NaN  ...  内神田     ＪＲ山手線       神田駅           4  東京メトロ丸ノ内線     大手町駅
# 1  20000.0 NaN  ...  内神田     ＪＲ山手線       神田駅           4  東京メトロ丸ノ内線     大手町駅
#
#   アクセス①2徒歩(分) アクセス①3線路名 アクセス①3駅名 アクセス①3徒歩(分)
# 0           6     ＪＲ山手線      東京駅        14.0
# 1           6     ＪＲ山手線      東京駅        14.0
#
# [2 rows x 27 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   名称           640 non-null    object
#  1   カテゴリ         640 non-null    object
#  2   アドレス         640 non-null    object
#  3   アクセス         640 non-null    object
#  4   築年数          640 non-null    int64
#  5   構造           640 non-null    int64
#  6   階数           639 non-null    float64
#  7   家賃           640 non-null    float64
#  8   管理費          612 non-null    float64
#  9   敷金           531 non-null    float64
#  10  礼金           337 non-null    float64
#  11  間取り          640 non-null    object
#  12  面積           640 non-null    float64
#  13  物件画像URL      640 non-null    object
#  14  間取画像URL      640 non-null    object
#  15  物件詳細URL      640 non-null    object
#  16  区            640 non-null    object
#  17  市町           640 non-null    object
#  18  アクセス①1線路名    640 non-null    object
#  19  アクセス①1駅名     640 non-null    object
#  20  アクセス①1徒歩(分)  640 non-null    int64
#  21  アクセス①2線路名    640 non-null    object
#  22  アクセス①2駅名     640 non-null    object
#  23  アクセス①2徒歩(分)  640 non-null    int64
#  24  アクセス①3線路名    640 non-null    object
#  25  アクセス①3駅名     618 non-null    object
#  26  アクセス①3徒歩(分)  618 non-null    float64
# dtypes: float64(7), int64(4), object(16)
# memory usage: 135.1+ KB

# %%
# 取得した不動産データの書き込み
SP_SHEET_wr     = 'test_datacleansing' # sheet名
worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
set_with_dataframe(worksheet_wr, new_df)

# %%
# 不動産データの取得
SP_SHEET     = 'test_datacleansing' # sheet名
worksheet = sh.worksheet(SP_SHEET) # シートのデータ取得
pre_data  = worksheet.get_all_values()
col_name = pre_data[0][:]
new_df = pd.DataFrame(pre_data[1:], columns=col_name) # 一段目をカラム、以下データフレームで取得

# %%
# ジオコーダーの初期化
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="MoveMate")

current_count = 0
total_count = len(new_df['アドレス'])


# 住所から緯度と経度を取得する関数
def get_lat_lon(address):
    global current_count
    current_count += 1

    try:
        location = geolocator.geocode(address)
        print(f"{current_count}/{total_count} 件目実施中 結果: {location.latitude}, {location.longitude}")

        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except Exception as e:
        print(f"Error retrieving location for address {address}: {e}")
        return None, None

# %%
from geopy.geocoders import Nominatim
import ssl
import certifi

# SSLコンテキストの作成
ctx = ssl.create_default_context(cafile=certifi.where())

# ジオコーダーの初期化（最新の証明書を使用）
geolocator = Nominatim(user_agent="MoveMate", ssl_context=ctx)

# %%
location = geolocator.geocode("東京都千代田区内神田２")
print(location)
# Out:
# 荻元医院, 14, 内神田二丁目, 内神田, 千代田区, 東京都, 101-0047, 日本

# %%
# 住所列があると仮定して、緯度経度列をデータフレームに追加
new_df['latitude'], new_df['longitude'] = zip(*new_df['アドレス'].apply(get_lat_lon))
# Out:
# 1/640 件目実施中 結果: 35.6902971, 139.7687921
# 2/640 件目実施中 結果: 35.6902971, 139.7687921
# 3/640 件目実施中 結果: 35.6902971, 139.7687921
# 4/640 件目実施中 結果: 35.6986625, 139.7492735
# 5/640 件目実施中 結果: 35.6986625, 139.7492735
# 6/640 件目実施中 結果: 35.6986625, 139.7492735
# 7/640 件目実施中 結果: 35.6986625, 139.7492735
# 8/640 件目実施中 結果: 35.6986625, 139.7492735
# 9/640 件目実施中 結果: 35.6986625, 139.7492735
# 10/640 件目実施中 結果: 35.6953456, 139.7611134
# 11/640 件目実施中 結果: 35.6953456, 139.7611134
# 12/640 件目実施中 結果: 35.6953456, 139.7611134
# 13/640 件目実施中 結果: 35.6953456, 139.7611134
# 14/640 件目実施中 結果: 35.6953456, 139.7611134
# 15/640 件目実施中 結果: 35.6953456, 139.7611134
# 16/640 件目実施中 結果: 35.6953456, 139.7611134
# 17/640 件目実施中 結果: 35.6953456, 139.7611134
# 18/640 件目実施中 結果: 35.6953456, 139.7611134
# 19/640 件目実施中 結果: 35.6953456, 139.7611134
# 20/640 件目実施中 結果: 35.6953456, 139.7611134
# 21/640 件目実施中 結果: 35.6953456, 139.7611134
# 22/640 件目実施中 結果: 35.6953456, 139.7611134
# 23/640 件目実施中 結果: 35.6953456, 139.7611134
# 24/640 件目実施中 結果: 35.6953456, 139.7611134
# 25/640 件目実施中 結果: 35.6953456, 139.7611134
# 26/640 件目実施中 結果: 35.6953456, 139.7611134
# 27/640 件目実施中 結果: 35.6953456, 139.7611134
# 28/640 件目実施中 結果: 35.6953456, 139.7611134
# 29/640 件目実施中 結果: 35.6953456, 139.7611134
# 30/640 件目実施中 結果: 35.6953456, 139.7611134
# 31/640 件目実施中 結果: 35.6953456, 139.7611134
# 32/640 件目実施中 結果: 35.6953456, 139.7611134
# 33/640 件目実施中 結果: 35.6953456, 139.7611134
# 34/640 件目実施中 結果: 35.6953456, 139.7611134
# 35/640 件目実施中 結果: 35.6953456, 139.7611134
# 36/640 件目実施中 結果: 35.6953456, 139.7611134
# 37/640 件目実施中 結果: 35.6953456, 139.7611134
# 38/640 件目実施中 結果: 35.6953456, 139.7611134
# 39/640 件目実施中 結果: 35.6953456, 139.7611134
# 40/640 件目実施中 結果: 35.6953456, 139.7611134
# 41/640 件目実施中 結果: 35.6953456, 139.7611134
# 42/640 件目実施中 結果: 35.6953456, 139.7611134
# 43/640 件目実施中 結果: 35.6953456, 139.7611134
# 44/640 件目実施中 結果: 35.6991447, 139.7531993
# 45/640 件目実施中 結果: 35.6991447, 139.7531993
# 46/640 件目実施中 結果: 35.6991447, 139.7531993
# 47/640 件目実施中 結果: 35.6991447, 139.7531993
# 48/640 件目実施中 結果: 35.6991447, 139.7531993
# 49/640 件目実施中 結果: 35.6991447, 139.7531993
# 50/640 件目実施中 結果: 35.6991447, 139.7531993
# 51/640 件目実施中 結果: 35.6991447, 139.7531993
# 52/640 件目実施中 結果: 35.6991447, 139.7531993
# 53/640 件目実施中 結果: 35.6991447, 139.7531993
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# 55/640 件目実施中 結果: 35.7013703, 139.7691497
# 56/640 件目実施中 結果: 35.7013703, 139.7691497
# 57/640 件目実施中 結果: 35.7013703, 139.7691497
# 58/640 件目実施中 結果: 35.7013703, 139.7691497
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# 67/640 件目実施中 結果: 35.6936145, 139.7734213
# 68/640 件目実施中 結果: 35.6936145, 139.7734213
# 69/640 件目実施中 結果: 35.6936145, 139.7734213
# 70/640 件目実施中 結果: 35.6936145, 139.7734213
# 71/640 件目実施中 結果: 35.6936145, 139.7734213
# 72/640 件目実施中 結果: 35.6953456, 139.7611134
# 73/640 件目実施中 結果: 35.6953456, 139.7611134
# 74/640 件目実施中 結果: 35.6953456, 139.7611134
# 75/640 件目実施中 結果: 35.6953456, 139.7611134
# 76/640 件目実施中 結果: 35.6953456, 139.7611134
# 77/640 件目実施中 結果: 35.6953456, 139.7611134
# 78/640 件目実施中 結果: 35.6953456, 139.7611134
# 79/640 件目実施中 結果: 35.6953456, 139.7611134
# 80/640 件目実施中 結果: 35.6953456, 139.7611134
# 81/640 件目実施中 結果: 35.6953456, 139.7611134
# 82/640 件目実施中 結果: 35.6953456, 139.7611134
# 83/640 件目実施中 結果: 35.6953456, 139.7611134
# 84/640 件目実施中 結果: 35.6953456, 139.7611134
# 85/640 件目実施中 結果: 35.6953456, 139.7611134
# 86/640 件目実施中 結果: 35.6953456, 139.7611134
# 87/640 件目実施中 結果: 35.6953456, 139.7611134
# 88/640 件目実施中 結果: 35.6953456, 139.7611134
# 89/640 件目実施中 結果: 35.6953456, 139.7611134
# 90/640 件目実施中 結果: 35.6953456, 139.7611134
# 91/640 件目実施中 結果: 35.6953456, 139.7611134
# 92/640 件目実施中 結果: 35.6953456, 139.7611134
# 93/640 件目実施中 結果: 35.6953456, 139.7611134
# 94/640 件目実施中 結果: 35.6953456, 139.7611134
# 95/640 件目実施中 結果: 35.6953456, 139.7611134
# 96/640 件目実施中 結果: 35.6953456, 139.7611134
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# 99/640 件目実施中 結果: 35.7013703, 139.7691497
# 100/640 件目実施中 結果: 35.7013703, 139.7691497
# 101/640 件目実施中 結果: 35.7016249, 139.770876
# 102/640 件目実施中 結果: 35.7016249, 139.770876
# 103/640 件目実施中 結果: 35.6956359, 139.7792834
# 104/640 件目実施中 結果: 35.6956359, 139.7792834
# 105/640 件目実施中 結果: 35.6956359, 139.7792834
# 106/640 件目実施中 結果: 35.6956359, 139.7792834
# 107/640 件目実施中 結果: 35.6956359, 139.7792834
# 108/640 件目実施中 結果: 35.6956359, 139.7792834
# 109/640 件目実施中 結果: 35.6956359, 139.7792834
# 110/640 件目実施中 結果: 35.6956359, 139.7792834
# 111/640 件目実施中 結果: 35.6956359, 139.7792834
# 112/640 件目実施中 結果: 35.6956359, 139.7792834
# 113/640 件目実施中 結果: 35.6956359, 139.7792834
# 114/640 件目実施中 結果: 35.6956359, 139.7792834
# 115/640 件目実施中 結果: 35.6956359, 139.7792834
# 116/640 件目実施中 結果: 35.6956359, 139.7792834
# 117/640 件目実施中 結果: 35.6956359, 139.7792834
# 118/640 件目実施中 結果: 35.6956359, 139.7792834
# 119/640 件目実施中 結果: 35.6956359, 139.7792834
# 120/640 件目実施中 結果: 35.6956359, 139.7792834
# 121/640 件目実施中 結果: 35.6956359, 139.7792834
# 122/640 件目実施中 結果: 35.6956359, 139.7792834
# 123/640 件目実施中 結果: 35.6956359, 139.7792834
# 124/640 件目実施中 結果: 35.6956359, 139.7792834
# 125/640 件目実施中 結果: 35.6956359, 139.7792834
# 126/640 件目実施中 結果: 35.6956359, 139.7792834
# 127/640 件目実施中 結果: 35.6956359, 139.7792834
# 128/640 件目実施中 結果: 35.6956359, 139.7792834
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# 150/640 件目実施中 結果: 35.6975054, 139.74443027253386
# 151/640 件目実施中 結果: 35.704980199999994, 139.77142798707865
# 152/640 件目実施中 結果: 35.704980199999994, 139.77142798707865
# 153/640 件目実施中 結果: 35.704980199999994, 139.77142798707865
# 154/640 件目実施中 結果: 35.704980199999994, 139.77142798707865
# 155/640 件目実施中 結果: 35.704980199999994, 139.77142798707865
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# 157/640 件目実施中 結果: 35.7016249, 139.770876
# 158/640 件目実施中 結果: 35.7016249, 139.770876
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# 167/640 件目実施中 結果: 35.6956359, 139.7792834
# 168/640 件目実施中 結果: 35.6956359, 139.7792834
# 169/640 件目実施中 結果: 35.6956359, 139.7792834
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# 187/640 件目実施中 結果: 35.6902971, 139.7687921
# 188/640 件目実施中 結果: 35.6975054, 139.74443027253386
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# 190/640 件目実施中 結果: 35.6948345, 139.7581026
# 191/640 件目実施中 結果: 35.6948345, 139.7581026
# 192/640 件目実施中 結果: 35.6948345, 139.7581026
# 193/640 件目実施中 結果: 35.6948345, 139.7581026
# 194/640 件目実施中 結果: 35.6948345, 139.7581026
# 195/640 件目実施中 結果: 35.6948345, 139.7581026
# 196/640 件目実施中 結果: 35.6948345, 139.7581026
# 197/640 件目実施中 結果: 35.6948345, 139.7581026
# 198/640 件目実施中 結果: 35.6948345, 139.7581026
# 199/640 件目実施中 結果: 35.6948345, 139.7581026
# 200/640 件目実施中 結果: 35.6948345, 139.7581026
# 201/640 件目実施中 結果: 35.6948345, 139.7581026
# 202/640 件目実施中 結果: 35.6948345, 139.7581026
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# 215/640 件目実施中 結果: 35.69663715, 139.77681027491053
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# 228/640 件目実施中 結果: 35.7013703, 139.7691497
# 229/640 件目実施中 結果: 35.7013703, 139.7691497
# 230/640 件目実施中 結果: 35.7013703, 139.7691497
# 231/640 件目実施中 結果: 35.7013703, 139.7691497
# 232/640 件目実施中 結果: 35.7013703, 139.7691497
# 233/640 件目実施中 結果: 35.7013703, 139.7691497
# 234/640 件目実施中 結果: 35.7013703, 139.7691497
# 235/640 件目実施中 結果: 35.7013703, 139.7691497
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田司町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町４: 'NoneType' object has no attribute 'latitude'
# 255/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 256/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 257/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 258/640 件目実施中 結果: 35.69663715, 139.77681027491053
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町２: 'NoneType' object has no attribute 'latitude'
# 265/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 266/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 267/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 268/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 269/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 270/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 271/640 件目実施中 結果: 35.6833509, 139.74371213650969
# Error retrieving location for address 東京都千代田区西神田３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区西神田３: 'NoneType' object has no attribute 'latitude'
# 274/640 件目実施中 結果: 35.70155, 139.77192079999998
# 275/640 件目実施中 結果: 35.70155, 139.77192079999998
# 276/640 件目実施中 結果: 35.6948345, 139.7581026
# 277/640 件目実施中 結果: 35.7013703, 139.7691497
# 278/640 件目実施中 結果: 35.7013703, 139.7691497
# 279/640 件目実施中 結果: 35.7013703, 139.7691497
# Error retrieving location for address 東京都千代田区九段南３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段南３: 'NoneType' object has no attribute 'latitude'
# 282/640 件目実施中 結果: 35.6956359, 139.7792834
# 283/640 件目実施中 結果: 35.6956359, 139.7792834
# 284/640 件目実施中 結果: 35.6956359, 139.7792834
# 285/640 件目実施中 結果: 35.6956359, 139.7792834
# 286/640 件目実施中 結果: 35.6956359, 139.7792834
# 287/640 件目実施中 結果: 35.6956359, 139.7792834
# 288/640 件目実施中 結果: 35.6956359, 139.7792834
# 289/640 件目実施中 結果: 35.6956359, 139.7792834
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# 293/640 件目実施中 結果: 35.6833509, 139.74371213650969
# 294/640 件目実施中 結果: 35.6833509, 139.74371213650969
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田錦町１: 'NoneType' object has no attribute 'latitude'
# 300/640 件目実施中 結果: 35.6944834, 139.7736525
# 301/640 件目実施中 結果: 35.6944834, 139.7736525
# 302/640 件目実施中 結果: 35.6944834, 139.7736525
# 303/640 件目実施中 結果: 35.6944834, 139.7736525
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# 307/640 件目実施中 結果: 35.6956359, 139.7792834
# 308/640 件目実施中 結果: 35.6956359, 139.7792834
# 309/640 件目実施中 結果: 35.6956359, 139.7792834
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# 314/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 315/640 件目実施中 結果: 35.69663715, 139.77681027491053
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# 324/640 件目実施中 結果: 35.6944834, 139.7736525
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# 326/640 件目実施中 結果: 35.6902971, 139.7687921
# 327/640 件目実施中 結果: 35.6902971, 139.7687921
# 328/640 件目実施中 結果: 35.6902971, 139.7687921
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# 346/640 件目実施中 結果: 35.6994859, 139.7633454
# 347/640 件目実施中 結果: 35.6994859, 139.7633454
# 348/640 件目実施中 結果: 35.6994859, 139.7633454
# 349/640 件目実施中 結果: 35.6994859, 139.7633454
# 350/640 件目実施中 結果: 35.6994859, 139.7633454
# 351/640 件目実施中 結果: 35.6994859, 139.7633454
# 352/640 件目実施中 結果: 35.6994859, 139.7633454
# 353/640 件目実施中 結果: 35.6994859, 139.7633454
# 354/640 件目実施中 結果: 35.6994859, 139.7633454
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町２: 'NoneType' object has no attribute 'latitude'
# 359/640 件目実施中 結果: 35.6902971, 139.7687921
# 360/640 件目実施中 結果: 35.6902971, 139.7687921
# 361/640 件目実施中 結果: 35.6902971, 139.7687921
# 362/640 件目実施中 結果: 35.6902971, 139.7687921
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# 376/640 件目実施中 結果: 35.6948345, 139.7581026
# 377/640 件目実施中 結果: 35.6948345, 139.7581026
# 378/640 件目実施中 結果: 35.6948345, 139.7581026
# 379/640 件目実施中 結果: 35.6948345, 139.7581026
# 380/640 件目実施中 結果: 35.6948345, 139.7581026
# 381/640 件目実施中 結果: 35.6948345, 139.7581026
# 382/640 件目実施中 結果: 35.6948345, 139.7581026
# 383/640 件目実施中 結果: 35.6948345, 139.7581026
# 384/640 件目実施中 結果: 35.6948345, 139.7581026
# 385/640 件目実施中 結果: 35.6948345, 139.7581026
# 386/640 件目実施中 結果: 35.6948345, 139.7581026
# 387/640 件目実施中 結果: 35.6948345, 139.7581026
# 388/640 件目実施中 結果: 35.6994859, 139.7633454
# 389/640 件目実施中 結果: 35.6994859, 139.7633454
# 390/640 件目実施中 結果: 35.6994859, 139.7633454
# 391/640 件目実施中 結果: 35.6994859, 139.7633454
# 392/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 393/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 394/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 395/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 396/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 397/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 398/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 399/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 400/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 401/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 402/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 403/640 件目実施中 結果: 35.6991895, 139.7531918213028
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# 405/640 件目実施中 結果: 35.6964881, 139.7617572
# 406/640 件目実施中 結果: 35.6964881, 139.7617572
# 407/640 件目実施中 結果: 35.6964881, 139.7617572
# 408/640 件目実施中 結果: 35.6964881, 139.7617572
# Error retrieving location for address 東京都千代田区一番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区一番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# 424/640 件目実施中 結果: 35.7016249, 139.770876
# 425/640 件目実施中 結果: 35.7016249, 139.770876
# 426/640 件目実施中 結果: 35.7016249, 139.770876
# Error retrieving location for address 東京都千代田区岩本町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# 433/640 件目実施中 結果: 35.6984324, 139.74549693966742
# 434/640 件目実施中 結果: 35.6984324, 139.74549693966742
# 435/640 件目実施中 結果: 35.6984324, 139.74549693966742
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# 444/640 件目実施中 結果: 35.7013703, 139.7691497
# 445/640 件目実施中 結果: 35.7013703, 139.7691497
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区岩本町１: 'NoneType' object has no attribute 'latitude'
# 451/640 件目実施中 結果: 35.6953456, 139.7611134
# 452/640 件目実施中 結果: 35.6956359, 139.7792834
# 453/640 件目実施中 結果: 35.6956359, 139.7792834
# 454/640 件目実施中 結果: 35.6956359, 139.7792834
# 455/640 件目実施中 結果: 35.6956359, 139.7792834
# 456/640 件目実施中 結果: 35.6956359, 139.7792834
# 457/640 件目実施中 結果: 35.6956359, 139.7792834
# 458/640 件目実施中 結果: 35.6956359, 139.7792834
# 459/640 件目実施中 結果: 35.6956359, 139.7792834
# Error retrieving location for address 東京都千代田区平河町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町１: 'NoneType' object has no attribute 'latitude'
# 462/640 件目実施中 結果: 35.6964881, 139.7617572
# 463/640 件目実施中 結果: 35.6973905, 139.7562923
# 464/640 件目実施中 結果: 35.6973905, 139.7562923
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田小川町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区平河町２: 'NoneType' object has no attribute 'latitude'
# 484/640 件目実施中 結果: 35.6948345, 139.7581026
# Error retrieving location for address 東京都千代田区西神田３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区西神田３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区西神田３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区西神田３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段北１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# 497/640 件目実施中 結果: 35.6936145, 139.7734213
# 498/640 件目実施中 結果: 35.6936145, 139.7734213
# 499/640 件目実施中 結果: 35.6936145, 139.7734213
# 500/640 件目実施中 結果: 35.6936145, 139.7734213
# 501/640 件目実施中 結果: 35.6936145, 139.7734213
# 502/640 件目実施中 結果: 35.6947126, 139.7555399
# 503/640 件目実施中 結果: 35.6947126, 139.7555399
# 504/640 件目実施中 結果: 35.6953456, 139.7611134
# 505/640 件目実施中 結果: 35.6953456, 139.7611134
# 506/640 件目実施中 結果: 35.6953456, 139.7611134
# 507/640 件目実施中 結果: 35.6953456, 139.7611134
# 508/640 件目実施中 結果: 35.6953456, 139.7611134
# 509/640 件目実施中 結果: 35.6953456, 139.7611134
# 510/640 件目実施中 結果: 35.6953456, 139.7611134
# 511/640 件目実施中 結果: 35.6953456, 139.7611134
# 512/640 件目実施中 結果: 35.6953456, 139.7611134
# 513/640 件目実施中 結果: 35.6953456, 139.7611134
# 514/640 件目実施中 結果: 35.6953456, 139.7611134
# 515/640 件目実施中 結果: 35.6953456, 139.7611134
# 516/640 件目実施中 結果: 35.6953456, 139.7611134
# 517/640 件目実施中 結果: 35.6953456, 139.7611134
# 518/640 件目実施中 結果: 35.6953456, 139.7611134
# 519/640 件目実施中 結果: 35.6953456, 139.7611134
# 520/640 件目実施中 結果: 35.6953456, 139.7611134
# 521/640 件目実施中 結果: 35.6953456, 139.7611134
# 522/640 件目実施中 結果: 35.6953456, 139.7611134
# 523/640 件目実施中 結果: 35.6953456, 139.7611134
# 524/640 件目実施中 結果: 35.6953456, 139.7611134
# 525/640 件目実施中 結果: 35.6953456, 139.7611134
# 526/640 件目実施中 結果: 35.6953456, 139.7611134
# 527/640 件目実施中 結果: 35.6953456, 139.7611134
# 528/640 件目実施中 結果: 35.6953456, 139.7611134
# 529/640 件目実施中 結果: 35.6953456, 139.7611134
# 530/640 件目実施中 結果: 35.6953456, 139.7611134
# 531/640 件目実施中 結果: 35.6953456, 139.7611134
# 532/640 件目実施中 結果: 35.6953456, 139.7611134
# 533/640 件目実施中 結果: 35.6953456, 139.7611134
# 534/640 件目実施中 結果: 35.6953456, 139.7611134
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区東神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# 541/640 件目実施中 結果: 35.6953456, 139.7611134
# 542/640 件目実施中 結果: 35.6953456, 139.7611134
# 543/640 件目実施中 結果: 35.6953456, 139.7611134
# 544/640 件目実施中 結果: 35.6953456, 139.7611134
# 545/640 件目実施中 結果: 35.6953456, 139.7611134
# 546/640 件目実施中 結果: 35.6953456, 139.7611134
# 547/640 件目実施中 結果: 35.6953456, 139.7611134
# 548/640 件目実施中 結果: 35.6953456, 139.7611134
# 549/640 件目実施中 結果: 35.6953456, 139.7611134
# 550/640 件目実施中 結果: 35.6953456, 139.7611134
# 551/640 件目実施中 結果: 35.6953456, 139.7611134
# 552/640 件目実施中 結果: 35.6953456, 139.7611134
# 553/640 件目実施中 結果: 35.6953456, 139.7611134
# 554/640 件目実施中 結果: 35.6953456, 139.7611134
# 555/640 件目実施中 結果: 35.6953456, 139.7611134
# 556/640 件目実施中 結果: 35.6953456, 139.7611134
# 557/640 件目実施中 結果: 35.6953456, 139.7611134
# 558/640 件目実施中 結果: 35.6953456, 139.7611134
# 559/640 件目実施中 結果: 35.6953456, 139.7611134
# 560/640 件目実施中 結果: 35.6953456, 139.7611134
# 561/640 件目実施中 結果: 35.6953456, 139.7611134
# 562/640 件目実施中 結果: 35.6953456, 139.7611134
# 563/640 件目実施中 結果: 35.6953456, 139.7611134
# 564/640 件目実施中 結果: 35.6953456, 139.7611134
# 565/640 件目実施中 結果: 35.6953456, 139.7611134
# 566/640 件目実施中 結果: 35.6953456, 139.7611134
# 567/640 件目実施中 結果: 35.6953456, 139.7611134
# 568/640 件目実施中 結果: 35.6953456, 139.7611134
# 569/640 件目実施中 結果: 35.6953456, 139.7611134
# 570/640 件目実施中 結果: 35.6953456, 139.7611134
# 571/640 件目実施中 結果: 35.6953456, 139.7611134
# 572/640 件目実施中 結果: 35.7016249, 139.770876
# 573/640 件目実施中 結果: 35.7016249, 139.770876
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区内神田１: 'NoneType' object has no attribute 'latitude'
# 577/640 件目実施中 結果: 35.6991895, 139.7531918213028
# 578/640 件目実施中 結果: 35.7013703, 139.7691497
# 579/640 件目実施中 結果: 35.7013703, 139.7691497
# 580/640 件目実施中 結果: 35.6994859, 139.7633454
# 581/640 件目実施中 結果: 35.6994859, 139.7633454
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# 584/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 585/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 586/640 件目実施中 結果: 35.69663715, 139.77681027491053
# Error retrieving location for address 東京都千代田区麹町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区麹町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# 592/640 件目実施中 結果: 35.6986625, 139.7492735
# 593/640 件目実施中 結果: 35.6986625, 139.7492735
# 594/640 件目実施中 結果: 35.6956359, 139.7792834
# 595/640 件目実施中 結果: 35.6956359, 139.7792834
# 596/640 件目実施中 結果: 35.6956359, 139.7792834
# 597/640 件目実施中 結果: 35.6956359, 139.7792834
# 598/640 件目実施中 結果: 35.6956359, 139.7792834
# 599/640 件目実施中 結果: 35.6956359, 139.7792834
# 600/640 件目実施中 結果: 35.6956359, 139.7792834
# Error retrieving location for address 東京都千代田区九段南２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区九段南２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田須田町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区三番町: 'NoneType' object has no attribute 'latitude'
# 609/640 件目実施中 結果: 35.691334, 139.774244
# 610/640 件目実施中 結果: 35.691334, 139.774244
# 611/640 件目実施中 結果: 35.691334, 139.774244
# 612/640 件目実施中 結果: 35.691334, 139.774244
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田佐久間町３: 'NoneType' object has no attribute 'latitude'
# 616/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 617/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 618/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 619/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 620/640 件目実施中 結果: 35.69663715, 139.77681027491053
# 621/640 件目実施中 結果: 35.6953456, 139.7611134
# 622/640 件目実施中 結果: 35.6953456, 139.7611134
# 623/640 件目実施中 結果: 35.6953456, 139.7611134
# 624/640 件目実施中 結果: 35.6953456, 139.7611134
# 625/640 件目実施中 結果: 35.6953456, 139.7611134
# 626/640 件目実施中 結果: 35.6774073, 139.7373736
# 627/640 件目実施中 結果: 35.6774073, 139.7373736
# Error retrieving location for address 東京都千代田区二番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区二番町: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区二番町: 'NoneType' object has no attribute 'latitude'
# 631/640 件目実施中 結果: 35.6937064, 139.7724147
# 632/640 件目実施中 結果: 35.6937064, 139.7724147
# 633/640 件目実施中 結果: 35.6937064, 139.7724147
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都千代田区神田多町２: 'NoneType' object has no attribute 'latitude'

# %%
# 取得した不動産データの書き込み
SP_SHEET_wr     = '緯度・経度取得' # sheet名
worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
set_with_dataframe(worksheet_wr, new_df)
